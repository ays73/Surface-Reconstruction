# %%
import mitsuba as mi
from src.mitsuba_render_h5 import render_scene
from matplotlib import pyplot as plt
import PIL
# Out:
# [mitsuba] Warning: Couldn't import the ipywidgets package. Installing this package is required for the system to properly log messages and print in Jupyter notebooks!

# %%
mi.set_variant('scalar_rgb')

# %%
obj_path = "demo_scene/scene10.obj"
xml_light_path = "demo_scene/scene10.xml"
output_img = "demo_scene/scene10_render.png"

# %%
r = render_scene(obj_path, xml_light_path)

# %%
plt.imshow(r)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..6.839544].
